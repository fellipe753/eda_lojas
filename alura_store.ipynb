# %% [markdown]
# # Análise exploratória de dados (*EDA*) de 4 lojas
#
# O projeto consiste em explorar os dados de 4 lojas e determinar qual delas é a indicada para ser vendida, visando mais eficiência no negócio.

# %% [markdown]
# # Importação das bibliotecas e dados
#
# **Dicionário de dados**
#
# * `Produto e Categoria` - Itens vendidos e suas classificações.
# * `Preço e Frete` - Valores das vendas e custos associados.
# * `Data de Compra e Local` - Informações temporais e geográficas.
# * `Avaliação da Compra` - Feedback dos clientes.
# * `Tipo de Pagamento e Parcelas` -  Métodos utilizados pelos clientes.
# * `Coordenadas Geográficasa` - Localização das transações.

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja1 = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja1.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %% [markdown]
# ## Renomeando as colunas
# Para facilitar a análise, são removidos os espaços e acentuações fica mais prático, facilitando a escrita do código.

# %%
nomes_colunas = [
    'produto', 'categoria_produto', 'preco', 'frete', 'data_compra',
    'vendedor', 'local_compra', 'avaliacao_compra', 'tipo_pagamento',
    'quantidade_parcelas', 'lat', 'lon'
]

lista_lojas = [loja1, loja2, loja3, loja4]
for i in range(len(lista_lojas)):
  lista_lojas[i].columns = nomes_colunas

loja4.head(1)
# Out:
#        produto categoria_produto    preco      frete data_compra  \
# 0  Lava louças  eletrodomesticos  1446.46  74.604083  11/11/2022
#
#        vendedor local_compra  avaliacao_compra  tipo_pagamento  \
# 0  Rafael Costa           SP                 4  cartao_credito
#
#    quantidade_parcelas    lat    lon
# 0                    3 -22.19 -48.79

# %% [markdown]
# ## Análise de colunas e linhas
# A coluna Data da Compra é do tipo Object, por isso transformo ela em date em
# todos os dataframes.

# %%
# linhas e colunas
print(f'A loja 1 possui {loja1.shape[0]} linhas e {loja1.shape[1]} colunas.')
print(f'A loja 2 possui {loja2.shape[0]} linhas e {loja2.shape[1]} colunas.')
print(f'A loja 3 possui {loja3.shape[0]} linhas e {loja3.shape[1]} colunas.')
print(f'A loja 4 possui {loja4.shape[0]} linhas e {loja4.shape[1]} colunas.')
# Out:
# A loja 1 possui 2359 linhas e 12 colunas.
# A loja 2 possui 2359 linhas e 12 colunas.
# A loja 3 possui 2359 linhas e 12 colunas.
# A loja 4 possui 2358 linhas e 12 colunas.

# %%
loja1.info()
print('\n')
loja2.info()
print('\n')
loja3.info()
print('\n')
loja4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   produto              2359 non-null   object
#  1   categoria_produto    2359 non-null   object
#  2   preco                2359 non-null   float64
#  3   frete                2359 non-null   float64
#  4   data_compra          2359 non-null   object
#  5   vendedor             2359 non-null   object
#  6   local_compra         2359 non-null   object
#  7   avaliacao_compra     2359 non-null   int64
#  8   tipo_pagamento       2359 non-null   object
#  9   quantidade_parcelas  2359 non-null   int64
#  10  lat                  2359 non-null   float64
#  11  lon                  2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   produto              2359 non-null   object
#  1   categoria_produto    2359 non-null   object
#  2   preco                2359 non-null   float64
#  3   frete                2359 non-null   float64
#  4   data_compra          2359 non-null   object
#  5   vendedor             2359 non-null   object
#  6   local_compra         2359 non-null   object
#  7   avaliacao_compra     2359 non-null   int64
#  8   tipo_pagamento       2359 non-null   object
#  9   quantidade_parcelas  2359 non-null   int64
#  10  lat                  2359 non-null   float64
#  11  lon                  2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   produto              2359 non-null   object
#  1   categoria_produto    2359 non-null   object
#  2   preco                2359 non-null   float64
#  3   frete                2359 non-null   float64
#  4   data_compra          2359 non-null   object
#  5   vendedor             2359 non-null   object
#  6   local_compra         2359 non-null   object
#  7   avaliacao_compra     2359 non-null   int64
#  8   tipo_pagamento       2359 non-null   object
#  9   quantidade_parcelas  2359 non-null   int64
#  10  lat                  2359 non-null   float64
#  11  lon                  2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   produto              2358 non-null   object
#  1   categoria_produto    2358 non-null   object
#  2   preco                2358 non-null   float64
#  3   frete                2358 non-null   float64
#  4   data_compra          2358 non-null   object
#  5   vendedor             2358 non-null   object
#  6   local_compra         2358 non-null   object
#  7   avaliacao_compra     2358 non-null   int64
#  8   tipo_pagamento       2358 non-null   object
#  9   quantidade_parcelas  2358 non-null   int64
#  10  lat                  2358 non-null   float64
#  11  lon                  2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# ## Análise dos campos numéricos
#
# O trecho `%config InteractiveShell.ast_node_interactivity = 'all'` permite que seja ilustrado os 4 describes em um só retorno da célula, evitando criar múltiplas células para isso.

# %%
# %config InteractiveShell.ast_node_interactivity = 'all'

# %%
loja1[['preco','frete','avaliacao_compra','quantidade_parcelas']].describe()
loja2[['preco','frete','avaliacao_compra','quantidade_parcelas']].describe()
loja3[['preco','frete','avaliacao_compra','quantidade_parcelas']].describe()
loja4[['preco','frete','avaliacao_compra','quantidade_parcelas']].describe()
# Out:
#              preco        frete  avaliacao_compra  quantidade_parcelas
# count  2359.000000  2359.000000       2359.000000          2359.000000
# mean    650.491361    34.691805          3.976685             2.943196
# std     819.582778    43.814183          1.415370             2.819897
# min      10.070000     0.000000          1.000000             1.000000
# 25%      74.345000     4.141783          3.000000             1.000000
# 50%     313.750000    16.498835          5.000000             1.000000
# 75%     904.130000    48.050074          5.000000             4.000000
# max    3969.380000   214.377060          5.000000            24.000000
#              preco        frete  avaliacao_compra  quantidade_parcelas
# count  2359.000000  2359.000000       2359.000000          2359.000000
# mean    630.970352    33.621941          4.037304             2.902501
# std     794.078997    42.321932          1.356153             2.848416
# min      10.160000     0.000000          1.000000             1.000000
# 25%      72.730000     3.904020          4.000000             1.000000
# 50%     290.960000    15.406740          5.000000             1.000000
# 75%     903.580000    47.250196          5.000000             4.000000
# max    3937.850000   216.707633          5.000000            24.000000
#              preco        frete  avaliacao_compra  quantidade_parcelas
# count  2359.000000  2359.000000       2359.000000          2359.000000
# mean    620.612560    33.074464          4.048326             2.967783
# std     774.191691    41.260516          1.386426             2.812153
# min      10.080000     0.000000          1.000000             1.000000
# 25%      76.560000     4.149261          4.000000             1.000000
# 50%     301.670000    15.879702          5.000000             2.000000
# 75%     888.040000    46.635503          5.000000             4.000000
# max    3957.620000   211.257624          5.000000            24.000000
#              preco        frete  avaliacao_compra  quantidade_parcelas
# count  2358.000000  2358.000000       2358.000000          2358.000000
# mean    587.149101    31.278997          3.995759             2.896098
# std     758.341290    40.373136          1.403063             2.730393
# min      10.170000     0.000000          1.000000             1.000000
# 25%      71.225000     3.847061          3.000000             1.000000
# 50%     279.315000    14.614197          5.000000             1.000000
# 75%     845.577500    44.438533          5.000000             4.000000
# max    3869.560000   206.325555          5.000000            18.000000

# %% [markdown]
# ## Verificação do percentual de registros nulos totais e por coluna
# Não temos nenhum valor nulo para nenhum registro, o que dispensa termos uma etapa para tratar os casos.

# %%
# percentual de nulos
(loja1.isnull().sum() / loja1.shape[0]).sort_values(ascending=False)
(loja2.isnull().sum() / loja2.shape[0]).sort_values(ascending=False)
(loja3.isnull().sum() / loja3.shape[0]).sort_values(ascending=False)
(loja4.isnull().sum() / loja4.shape[0]).sort_values(ascending=False)
# Out:
# produto                0.0
# categoria_produto      0.0
# preco                  0.0
# frete                  0.0
# data_compra            0.0
# vendedor               0.0
# local_compra           0.0
# avaliacao_compra       0.0
# tipo_pagamento         0.0
# quantidade_parcelas    0.0
# lat                    0.0
# lon                    0.0
# dtype: float64
# produto                0.0
# categoria_produto      0.0
# preco                  0.0
# frete                  0.0
# data_compra            0.0
# vendedor               0.0
# local_compra           0.0
# avaliacao_compra       0.0
# tipo_pagamento         0.0
# quantidade_parcelas    0.0
# lat                    0.0
# lon                    0.0
# dtype: float64
# produto                0.0
# categoria_produto      0.0
# preco                  0.0
# frete                  0.0
# data_compra            0.0
# vendedor               0.0
# local_compra           0.0
# avaliacao_compra       0.0
# tipo_pagamento         0.0
# quantidade_parcelas    0.0
# lat                    0.0
# lon                    0.0
# dtype: float64
# produto                0.0
# categoria_produto      0.0
# preco                  0.0
# frete                  0.0
# data_compra            0.0
# vendedor               0.0
# local_compra           0.0
# avaliacao_compra       0.0
# tipo_pagamento         0.0
# quantidade_parcelas    0.0
# lat                    0.0
# lon                    0.0
# dtype: float64

# %% [markdown]
# ## Tratamento da coluna data, criação de novas colunas de origem e novo dataframe unificado

# %%
# tratando a data
loja1['data_compra'] = pd.to_datetime(loja1['data_compra'], dayfirst=True)#"%d/%m/%Y")
loja2['data_compra'] = pd.to_datetime(loja2['data_compra'], dayfirst=True)
loja3['data_compra'] = pd.to_datetime(loja3['data_compra'], dayfirst=True)
loja4['data_compra'] = pd.to_datetime(loja4['data_compra'], dayfirst=True)

# %%
# adicionando uma coluna de origem e criando um novo dadtaframe com o union de todos
loja1['origem'] = 'Loja 1'
loja2['origem'] = 'Loja 2'
loja3['origem'] = 'Loja 3'
loja4['origem'] = 'Loja 4'

# novo dataframe unificado
lojas = pd.concat([loja1, loja2, loja3, loja4], ignore_index=True)

# %% [markdown]
# # Análise do faturamento
#
# Análise do faturamento das 4 lojas sem levar em consdieração o frete.
#
#     A loja1 teve R$ 1.534.509,12 de faturamento total. Sendo responsável por 26,13% do total das lojas.
#     A loja2 teve R$ 1.488.459,06 de faturamento total. Sendo responsável por 25,35% do total das lojas.
#     A loja3 teve R$ 1.464.025,03 de faturamento total. Sendo responsável por 24,93% do total das lojas.
#     A loja4 teve R$ 1.384.497,58 de faturamento total. Sendo responsável por 23,58% do total das lojas.
#     As lojas tiveram R$ 5.871.490,79 de faturamento total.

# %% [markdown]
# ## Faturamento por dia

# %%
# criando dataframe para o gráfico
lojas_agg_data_preco = lojas.groupby(['data_compra','origem'])['preco'].sum().reset_index()
# criando gráfico dinâmico
fig = px.line(lojas_agg_data_preco, x='data_compra', y='preco', color='origem')#, title='Receita das vendas por dia e loja')
fig.update_layout(title='Faturamento das lojas por dia',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f2e94093-e5af-40d9-bc60-ed24b7a3d836" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2e94093-e5af-40d9-bc60-ed24b7a3d836")) {                    Plotly.newPlot(                        "f2e94093-e5af-40d9-bc60-ed24b7a3d836",                        [{"hovertemplate":"origem=Loja 1\u003cbr\u003edata_compra=%{x}\u003cbr\u003epreco=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Loja 1","showlegend":true,"x":["2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-25T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-02T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-16T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T0 ...

# %% [markdown]
# ## Faturamento total

# %%
loja1_faturamento = loja1['preco'].sum()
loja2_faturamento = loja2['preco'].sum()
loja3_faturamento = loja3['preco'].sum()
loja4_faturamento = loja4['preco'].sum()
lojas_faturamento = lojas['preco'].sum()

print(f' A loja1 teve R$ {loja1_faturamento:,} de faturamento total. Sendo responsável por {loja1_faturamento/lojas_faturamento:.2%} do total das lojas.')
print(f' A loja2 teve R$ {loja2_faturamento:,} de faturamento total. Sendo responsável por {loja2_faturamento/lojas_faturamento:.2%} do total das lojas.')
print(f' A loja3 teve R$ {loja3_faturamento:,} de faturamento total. Sendo responsável por {loja3_faturamento/lojas_faturamento:.2%} do total das lojas.')
print(f' A loja4 teve R$ {loja4_faturamento:,} de faturamento total. Sendo responsável por {loja4_faturamento/lojas_faturamento:.2%} do total das lojas.')
print(f' As lojas tiveram R$ {round(lojas_faturamento,2):,} de faturamento total.')
# Out:
#  A loja1 teve R$ 1,534,509.12 de faturamento total. Sendo responsável por 26.13% do total das lojas.
#  A loja2 teve R$ 1,488,459.06 de faturamento total. Sendo responsável por 25.35% do total das lojas.
#  A loja3 teve R$ 1,464,025.03 de faturamento total. Sendo responsável por 24.93% do total das lojas.
#  A loja4 teve R$ 1,384,497.58 de faturamento total. Sendo responsável por 23.58% do total das lojas.
#  As lojas tiveram R$ 5,871,490.79 de faturamento total.

# %%
# criando dataframe para o gráfico
lojas_agg_origem_preco = lojas.groupby(['origem'])['preco'].sum().reset_index()
# criando gráfico dinâmico
fig = px.bar(lojas_agg_origem_preco, x='preco', y='origem', color='origem')
fig.update_layout(title='Faturamento total por loja',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7f0a451-9284-4ca6-96ed-5a9d1652a27b" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7f0a451-9284-4ca6-96ed-5a9d1652a27b")) {                    Plotly.newPlot(                        "e7f0a451-9284-4ca6-96ed-5a9d1652a27b",                        [{"alignmentgroup":"True","hovertemplate":"origem=%{y}\u003cbr\u003epreco=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Loja 1","offsetgroup":"Loja 1","orientation":"h","showlegend":true,"textposition":"auto","x":[1534509.12],"xaxis":"x","y":["Loja 1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=%{y}\u003cbr\u003epreco=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loja 2","offsetgroup":"Loja 2","orientation":"h","showlegend":true,"textposition":"auto","x":[1488459.06],"xaxis":"x","y":["Loja 2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=%{y}\u003cbr\u003epreco=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loja 3","offsetgroup":"Loja 3","orientation":"h","showlegend":true,"textposition":"auto","x":[1464025.03],"xaxis":"x","y":["Loja 3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=%{y}\u003cbr\u003epreco=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 4","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Loja 4","offsetgroup":"Loja 4","orientation":"h","showlegend":true,"textposition":"auto","x":[1384497.58],"xaxis":"x","y":["Loja 4"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7 ...

# %% [markdown]
# ## Maiores e menores vendas registradas

# %%
print(f'Loja1: A venda de menor valor foi: R$ {loja1["preco"].min():,} e a de maior valor foi: R$ {loja1["preco"].max():,}.')
print(f'Loja2: A venda de menor valor foi: R$ {loja2["preco"].min():,} e a de maior valor foi: R$ {loja2["preco"].max():,}.')
print(f'Loja3: A venda de menor valor foi: R$ {loja3["preco"].min():,} e a de maior valor foi: R$ {loja3["preco"].max():,}.')
print(f'Loja4: A venda de menor valor foi: R$ {loja4["preco"].min():,} e a de maior valor foi: R$ {loja4["preco"].max():,}.')
# Out:
# Loja1: A venda de menor valor foi: R$ 10.07 e a de maior valor foi: R$ 3,969.38.
# Loja2: A venda de menor valor foi: R$ 10.16 e a de maior valor foi: R$ 3,937.85.
# Loja3: A venda de menor valor foi: R$ 10.08 e a de maior valor foi: R$ 3,957.62.
# Loja4: A venda de menor valor foi: R$ 10.17 e a de maior valor foi: R$ 3,869.56.

# %% [markdown]
# # Vendas por categoria
#
#
#     Loja1: A categoria mais vendida foi moveis com 465 vendas(19.71%)..
#     A categoria menos vendida foi utilidades domesticas com 171 vendas(7.25%).
#
#     Loja2: A categoria mais vendida foi moveis com 442 vendas(18.74%)..
#     A categoria menos vendida foi utilidades domesticas com 181 vendas(7.67%).
#
#     Loja3: A categoria mais vendida foi moveis com 499 vendas(21.15%)..
#     A categoria menos vendida foi instrumentos musicais com 177 vendas(7.50%).
#
#     Loja4: A categoria mais vendida foi moveis com 480 vendas(20.36%)..
#     A categoria menos vendida foi instrumentos musicais com 170 vendas(7.21%).
#
# Importante ressaltar que apesar de móveis ser a categoria mais vendida, ela é apenas a terceira em faturamento.

# %% [markdown]
# ## Vendas por categoria

# %%
# funcao dos max e min vendas por categoria
def max_categoria(loja, nome_loja):
  loja_categoria = loja['categoria_produto'].value_counts()
  categoria_max = loja_categoria.idxmax()
  valor_max = loja_categoria.max()
  pct_vendas_max = valor_max / loja_categoria.sum()
  categoria_min = loja_categoria.idxmin()
  valor_min = loja_categoria.min()
  pct_vendas_min = valor_min / loja_categoria.sum()
  return print(f' {nome_loja}: A categoria mais vendida foi {categoria_max} com {valor_max} vendas({pct_vendas_max:.2%})'
  f'.\n A categoria menos vendida foi {categoria_min} com {valor_min} vendas({pct_vendas_min:.2%}).\n')

max_categoria(loja1, 'Loja 1')
max_categoria(loja2, 'Loja 2')
max_categoria(loja3, 'Loja 3')
max_categoria(loja4, 'Loja 4')

# {loja1_faturamento/lojas_faturamento:.2%} do total das lojas.')
# Out:
#  Loja 1: A categoria mais vendida foi moveis com 465 vendas(19.71%).
#  A categoria menos vendida foi utilidades domesticas com 171 vendas(7.25%).
#
#  Loja 2: A categoria mais vendida foi moveis com 442 vendas(18.74%).
#  A categoria menos vendida foi utilidades domesticas com 181 vendas(7.67%).
#
#  Loja 3: A categoria mais vendida foi moveis com 499 vendas(21.15%).
#  A categoria menos vendida foi instrumentos musicais com 177 vendas(7.50%).
#
#  Loja 4: A categoria mais vendida foi moveis com 480 vendas(20.36%).
#  A categoria menos vendida foi instrumentos musicais com 170 vendas(7.21%).

# %%
# criando dataframe para o gráfico
lojas_agg_origem_categoria = lojas.groupby(['categoria_produto'])['origem'].value_counts().reset_index().rename(columns={"count":"vendas"})
lojas_agg_origem_categoria = lojas_agg_origem_categoria.sort_values(by='vendas')
# criando gráfico dinâmico
fig = px.bar(lojas_agg_origem_categoria, x='vendas', y='categoria_produto', color='origem')
fig.update_layout(title='Vendas por categoria por loja',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1adb30ee-f739-4b84-881e-fa25e953a17e" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1adb30ee-f739-4b84-881e-fa25e953a17e")) {                    Plotly.newPlot(                        "1adb30ee-f739-4b84-881e-fa25e953a17e",                        [{"alignmentgroup":"True","hovertemplate":"origem=Loja 4\u003cbr\u003evendas=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 4","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Loja 4","offsetgroup":"Loja 4","orientation":"h","showlegend":true,"textposition":"auto","x":[170,187,201,254,277,338,451,480],"xaxis":"x","y":["instrumentos musicais","livros","utilidades domesticas","eletrodomesticos","esporte e lazer","brinquedos","eletronicos","moveis"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 1\u003cbr\u003evendas=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loja 1","offsetgroup":"Loja 1","orientation":"h","showlegend":true,"textposition":"auto","x":[171,173,182,284,312,324,448,465],"xaxis":"x","y":["utilidades domesticas","livros","instrumentos musicais","esporte e lazer","eletrodomesticos","brinquedos","eletronicos","moveis"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 3\u003cbr\u003evendas=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loja 3","offsetgroup":"Loja 3","orientation":"h","showlegend":true,"textposition":"auto","x":[177,177,185,277,278,315,451,499],"xaxis":"x","y":["instrumentos musicais","utilidades domesticas","livros","esporte e lazer","eletrodomesticos","brinquedos","eletronicos","moveis"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 2\u003cbr\u003evendas=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Loja 2","offsetgroup":"Loja 2","orientation":"h","showlegend":true,"textposition":"auto","x":[181,197,224,275,305,313,422,442],"xaxis":"x","y":["utilidades domesticas","livros","instrumentos musicais","esporte e lazer","eletrodomesticos","brinquedos","eletronicos","moveis"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl" ...

# %% [markdown]
# ## Faturamento por categoria

# %%
# criando dataframe para o gráfico
lojas_agg_origem_categoria = lojas.groupby(['categoria_produto','origem'])['preco'].sum().reset_index().rename(columns={"count":"vendas"})
lojas_agg_origem_categoria = lojas_agg_origem_categoria.sort_values(by='preco')
# criando gráfico dinâmico
fig = px.bar(lojas_agg_origem_categoria, x='preco', y='categoria_produto', color='origem')
fig.update_layout(title='Faturamento por categoria por loja',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a3b72ae-2ce2-4ace-a771-c17e2a309557" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a3b72ae-2ce2-4ace-a771-c17e2a309557")) {                    Plotly.newPlot(                        "5a3b72ae-2ce2-4ace-a771-c17e2a309557",                        [{"alignmentgroup":"True","hovertemplate":"origem=Loja 1\u003cbr\u003epreco=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Loja 1","offsetgroup":"Loja 1","orientation":"h","showlegend":true,"textposition":"auto","x":[11713.92,16931.48,23993.78,52387.55,121731.69,250178.11000000002,484913.36,572659.23],"xaxis":"x","y":["livros","utilidades domesticas","brinquedos","esporte e lazer","instrumentos musicais","moveis","eletrodomesticos","eletronicos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 4\u003cbr\u003epreco=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loja 4","offsetgroup":"Loja 4","orientation":"h","showlegend":true,"textposition":"auto","x":[12427.77,20098.83,27015.67,44465.65,100136.5,256705.65,377680.65,545966.86],"xaxis":"x","y":["livros","utilidades domesticas","brinquedos","esporte e lazer","instrumentos musicais","moveis","eletrodomesticos","eletronicos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 3\u003cbr\u003epreco=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loja 3","offsetgroup":"Loja 3","orientation":"h","showlegend":true,"textposition":"auto","x":[12664.7,20080.21,25869.2,47456.1,103174.45,268095.56,438984.89,547699.92],"xaxis":"x","y":["livros","utilidades domesticas","brinquedos","esporte e lazer","instrumentos musicais","moveis","eletrodomesticos","eletronicos"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 2\u003cbr\u003epreco=%{x}\u003cbr\u003ecategoria_produto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Loja 2","offsetgroup":"Loja 2","orientation":"h","showlegend":true,"textposition":"auto","x":[13454.35,19662.86,21262.21,46326.09,139987.03,235234.68,464758.13,547773.71],"xaxis":"x","y":["livros","utilidades domesticas","brinquedos","esporte e lazer","instrumentos musicais","moveis","eletrodomesticos","eletronicos"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %%
# vendas e faturamento
loja1.groupby('categoria_produto').agg(vendas=('preco','count'), faturamento=('preco','sum')).sort_values(by='vendas',ascending=False).reset_index()
loja2.groupby('categoria_produto').agg(vendas=('preco','count'), faturamento=('preco','sum')).sort_values(by='vendas',ascending=False).reset_index()
loja3.groupby('categoria_produto').agg(vendas=('preco','count'), faturamento=('preco','sum')).sort_values(by='vendas',ascending=False).reset_index()
loja4.groupby('categoria_produto').agg(vendas=('preco','count'), faturamento=('preco','sum')).sort_values(by='vendas',ascending=False).reset_index()
# Out:
#        categoria_produto  vendas  faturamento
# 0                 moveis     465    250178.11
# 1            eletronicos     448    572659.23
# 2             brinquedos     324     23993.78
# 3       eletrodomesticos     312    484913.36
# 4        esporte e lazer     284     52387.55
# 5  instrumentos musicais     182    121731.69
# 6                 livros     173     11713.92
# 7  utilidades domesticas     171     16931.48
#        categoria_produto  vendas  faturamento
# 0                 moveis     442    235234.68
# 1            eletronicos     422    547773.71
# 2             brinquedos     313     21262.21
# 3       eletrodomesticos     305    464758.13
# 4        esporte e lazer     275     46326.09
# 5  instrumentos musicais     224    139987.03
# 6                 livros     197     13454.35
# 7  utilidades domesticas     181     19662.86
#        categoria_produto  vendas  faturamento
# 0                 moveis     499    268095.56
# 1            eletronicos     451    547699.92
# 2             brinquedos     315     25869.20
# 3       eletrodomesticos     278    438984.89
# 4        esporte e lazer     277     47456.10
# 5                 livros     185     12664.70
# 6  instrumentos musicais     177    103174.45
# 7  utilidades domesticas     177     20080.21
#        categoria_produto  vendas  faturamento
# 0                 moveis     480    256705.65
# 1            eletronicos     451    545966.86
# 2             brinquedos     338     27015.67
# 3        esporte e lazer     277     44465.65
# 4       eletrodomesticos     254    377680.65
# 5  utilidades domesticas     201     20098.83
# 6                 livros     187     12427.77
# 7  instrumentos musicais     170    100136.50

# %% [markdown]
# # Média de avaliação das lojas
# A loja 3 tem a melhor nota média. Todas lojas tem mediana de 5, ou seja, metade das avaliações são 5 em todas as lojas.
#
#     Loja 1: A nota média das avaliações é 3.98 enquanto a mediana é 5.0.
#     Loja 2: A nota média das avaliações é 4.04 enquanto a mediana é 5.0.
#     Loja 3: A nota média das avaliações é 4.05 enquanto a mediana é 5.0.
#     Loja 4: A nota média das avaliações é 4.0 enquanto a mediana é 5.0.

# %%
def media_avaliacao(loja, nome_loja):
  loja_avaliacao_media = round(loja["avaliacao_compra"].mean(),2)
  loja_avaliacao_mediana = round(loja["avaliacao_compra"].median(),2)
  return print(f'{nome_loja}: A nota média das avaliações é {loja_avaliacao_media} enquanto a mediana é {loja_avaliacao_mediana}.')

media_avaliacao(loja1, 'Loja 1')
media_avaliacao(loja2, 'Loja 2')
media_avaliacao(loja3, 'Loja 3')
media_avaliacao(loja4, 'Loja 4')
# Out:
# Loja 1: A nota média das avaliações é 3.98 enquanto a mediana é 5.0.
# Loja 2: A nota média das avaliações é 4.04 enquanto a mediana é 5.0.
# Loja 3: A nota média das avaliações é 4.05 enquanto a mediana é 5.0.
# Loja 4: A nota média das avaliações é 4.0 enquanto a mediana é 5.0.

# %% [markdown]
# # Produtos mais e menos vendidos
#
#     Loja 1: O produto mais vendido foi Micro-ondas com 60 vendas(2.54%).
#     O produto menos vendido foi Headset com 33 vendas(1.40%).
#
#     Loja 2: O produto mais vendido foi Iniciando em programação com 65 vendas(2.76%).
#     O produto menos vendido foi Jogo de tabuleiro com 32 vendas(1.36%).
#
#     Loja 3: O produto mais vendido foi Kit banquetas com 57 vendas(2.42%).
#     O produto menos vendido foi Blocos de montar com 35 vendas(1.48%).
#
#     Loja 4: O produto mais vendido foi Cama box com 62 vendas(2.63%).
#     O produto menos vendido foi Guitarra com 33 vendas(1.40%).

# %%
def max_produto(loja, nome_loja):
  loja_produto = loja['produto'].value_counts()
  produto_max = loja_produto.idxmax()
  valor_max = loja_produto.max()
  pct_vendas_max = valor_max / loja_produto.sum()
  produto_min = loja_produto.idxmin()
  valor_min = loja_produto.min()
  pct_vendas_min = valor_min / loja_produto.sum()
  return print(f' {nome_loja}: O produto mais vendido foi {produto_max} com {valor_max} vendas({pct_vendas_max:.2%})'
  f'.\n O produto menos vendido foi {produto_min} com {valor_min} vendas({pct_vendas_min:.2%}).\n')

max_produto(loja1, 'Loja 1')
max_produto(loja2, 'Loja 2')
max_produto(loja3, 'Loja 3')
max_produto(loja4, 'Loja 4')
# Out:
#  Loja 1: O produto mais vendido foi Micro-ondas com 60 vendas(2.54%).
#  O produto menos vendido foi Headset com 33 vendas(1.40%).
#
#  Loja 2: O produto mais vendido foi Iniciando em programação com 65 vendas(2.76%).
#  O produto menos vendido foi Jogo de tabuleiro com 32 vendas(1.36%).
#
#  Loja 3: O produto mais vendido foi Kit banquetas com 57 vendas(2.42%).
#  O produto menos vendido foi Blocos de montar com 35 vendas(1.48%).
#
#  Loja 4: O produto mais vendido foi Cama box com 62 vendas(2.63%).
#  O produto menos vendido foi Guitarra com 33 vendas(1.40%).

# %% [markdown]
# ## Vendas por produto

# %%
# criando dataframe para o gráfico
lojas_agg_origem_produto = lojas.groupby(['produto'])['origem'].value_counts().reset_index().rename(columns={"count":"vendas"})
lojas_agg_origem_produto = lojas_agg_origem_produto.sort_values(by='vendas')
# criando gráfico dinâmico
fig = px.bar(lojas_agg_origem_produto, x='vendas', y='produto', color='origem')
fig.update_layout(title='Vendas por produto por loja',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d5bba8a0-4da5-4b65-b02d-5a7eeb0c5c5b" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5bba8a0-4da5-4b65-b02d-5a7eeb0c5c5b")) {                    Plotly.newPlot(                        "d5bba8a0-4da5-4b65-b02d-5a7eeb0c5c5b",                        [{"alignmentgroup":"True","hovertemplate":"origem=Loja 2\u003cbr\u003evendas=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Loja 2","offsetgroup":"Loja 2","orientation":"h","showlegend":true,"textposition":"auto","x":[32,34,34,35,37,38,39,40,41,42,42,42,43,43,44,44,44,44,44,44,45,45,45,45,45,45,45,45,46,46,46,46,47,47,47,47,48,49,49,49,50,52,54,54,55,57,58,58,61,62,65],"xaxis":"x","y":["Jogo de tabuleiro","Impressora","Mesa de jantar","Poltrona","Fone de ouvido","Assistente virtual","Faqueiro","Smart TV","Celular ABXY","Fogão","Dinossauro Rex","Bola de basquete","Dashboards com Power BI","Ciência de dados com python","Panela de pressão","Smartwatch","Sofá retrátil","Tablet ABXY","Cômoda","Headset","Cubo mágico 8x8","Bicicleta","Mesa de centro","Kit banquetas","Mochila","Xadrez de madeira","TV Led UHD 4K","Cama king","Jogo de copos","Lava louças","Bola de vôlei","Modelagem preditiva","Copo térmico","Guitarra","Cama box","Carrinho controle remoto","Boneca bebê","Lavadora de roupas","Geladeira","Cadeira de escritório","Corda de pular","Jogo de panelas","Blocos de montar","Guarda roupas","Celular Plus X42","Secadora de roupas","Violão","Pandeiro","Bateria","Micro-ondas","Iniciando em programação"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 1\u003cbr\u003evendas=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loja 1","offsetgroup":"Loja 1","orientation":"h","showlegend":true,"textposition":"auto","x":[33,33,35,36,39,39,40,40,40,40,40,41,41,41,42,42,42,43,43,43,44,44,44,44,44,44,45,46,46,46,47,47,48,49,49,50,51,52,52,53,54,54,54,54,55,56,56,58,60,60,60],"xaxis":"x","y":["Celular ABXY","Headset","Panela de pressão","Pandeiro","Mochila","Ciência de dados com python","Assistente virtual","Mesa de jantar","Boneca bebê","Dinossauro Rex","Corda de pular","Poltrona","Jogo de copos","Iniciando em programação","Bola de vôlei","Dashboards com Power BI","Tablet ABXY","Jogo de tabuleiro","Jogo de panelas","Smartwatch","Mesa de centro","Kit banquetas","Smart TV","Cubo mágico 8x8","Cama box","Cama king","Fogão","Violão","Cadeira de escritório","Sofá retrátil","Lavadora de roupas","Guitarra","Lava louças","Celular Plus X42","Xadrez de madeira","Fone de ouvido","Modelagem preditiva","Faqueiro","Carrinho controle remoto","Bateria","Geladeira","Bicicleta","Copo térmico","Impressora","Bola de basquete","Blocos de montar","Cômoda","Secadora de roupas","Micro-ondas","TV Led UHD 4K","Guarda roupas"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 4\u003cbr\u003evendas=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 4","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loja 4","offsetgroup":"Loja 4","orientation":"h","showlegend":true,"textposition":"auto","x":[33,34,37,38,38,38,39,39,39,40,40,40,42,42,43,43,43,43,44,44,45,45,45,46,46,47,47,47,47,48,48,48,48,48,48,48,50,50,50,50,50,52,54,54,55,55,55,56,56,59,62],"xaxis":"x","y":["Guitarra","Guarda roupas","Violão","Lavadora de roupas","Geladeira","Ciência de dados com python","Smartwatch","Xadrez de madeira","Celular ABXY","TV Led UHD 4K","Secadora de roupas","Cadeira de escritório","Headset","Kit banquetas","Iniciando e ...

# %% [markdown]
# ## Faturamento por produto

# %%
# criando dataframe para o gráfico
lojas_agg_origem_produto = lojas.groupby(['produto','origem'])['preco'].sum().reset_index().rename(columns={"count":"vendas"})
lojas_agg_origem_produto = lojas_agg_origem_produto.sort_values(by='preco')
# criando gráfico dinâmico
fig = px.bar(lojas_agg_origem_produto, x='preco', y='produto', color='origem')
fig.update_layout(title='Faturamento por categoria por loja',title_x=0.5,autosize=False,width=1300,height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1bfc7d96-aea7-42dc-8b41-56fc94121b1b" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bfc7d96-aea7-42dc-8b41-56fc94121b1b")) {                    Plotly.newPlot(                        "1bfc7d96-aea7-42dc-8b41-56fc94121b1b",                        [{"alignmentgroup":"True","hovertemplate":"origem=Loja 3\u003cbr\u003epreco=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 3","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Loja 3","offsetgroup":"Loja 3","orientation":"h","showlegend":true,"textposition":"auto","x":[853.8100000000001,1060.78,1137.76,1614.2,1649.81,1807.34,1829.81,2300.69,2368.26,2577.11,3048.36,3111.74,3286.59,3304.02,4326.9,4499.94,4502.71,4729.54,4960.74,5279.35,7960.16,9239.21,10684.06,10695.81,11595.04,12959.61,15111.19,18958.16,19101.4,19891.55,20487.18,22265.96,24501.63,25538.25,32249.71,32872.35,32933.14,39158.71,39797.29,40426.24,51430.37,51779.9,57893.04,66397.97,76612.58,77919.93,85819.73,105116.46,124300.84,128892.11,133185.99],"xaxis":"x","y":["Cubo mágico 8x8","Dinossauro Rex","Corda de pular","Jogo de copos","Blocos de montar","Xadrez de madeira","Dashboards com Power BI","Copo térmico","Faqueiro","Boneca bebê","Iniciando em programação","Bola de vôlei","Ciência de dados com python","Bola de basquete","Pandeiro","Modelagem preditiva","Panela de pressão","Mochila","Carrinho controle remoto","Fone de ouvido","Headset","Mesa de centro","Assistente virtual","Smartwatch","Jogo de panelas","Jogo de tabuleiro","Poltrona","Impressora","Mesa de jantar","Violão","Cômoda","Kit banquetas","Cadeira de escritório","Micro-ondas","Guarda roupas","Bicicleta","Cama box","Bateria","Guitarra","Sofá retrátil","Fogão","Cama king","Celular ABXY","Secadora de roupas","Lavadora de roupas","Tablet ABXY","Lava louças","Smart TV","Celular Plus X42","TV Led UHD 4K","Geladeira"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 2\u003cbr\u003epreco=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loja 2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Loja 2","offsetgroup":"Loja 2","orientation":"h","showlegend":true,"textposition":"auto","x":[858.22,1027.41,1142.54,1717.05,2056.69,2132.93,2310.25,2385.91,2788.23,2874.63,3052.62,3161.66,3198.42,3953.04,4169.96,4362.38,4676.44,4759.28,4967.0,5856.96,7525.9800000000005,7749.58,10241.06,10367.11,10572.47,10619.48,11218.0,11516.31,13846.69,16306.77,16806.13,24706.82,24864.13,30611.11,32476.36,34900.24,37618.26,39318.68,40131.16,48256.37,48589.03,55558.43,61566.87,74945.97,78357.0,78820.31,81522.94,89016.81,130176.48,137833.06,150967.83],"xaxis":"x","y":["Cubo mágico 8x8","Dinossauro Rex","Corda de pular","Xadrez de madeira","Jogo de copos","Dashboards com Power BI","Faqueiro","Blocos de montar","Bola de basquete","Copo térmico","Bola de vôlei","Boneca bebê","Ciência de dados com python","Modelagem preditiva","Iniciando em programação","Carrinho controle remoto","Panela de pressão","Fone de ouvido","Pandeiro","Mochila","Headset","Jogo de tabuleiro","Smartwatch","Mesa de centro","Assistente virtual","Jogo de panelas","Poltrona","Mesa de jantar","Impressora","Cômoda","Kit banquetas","Cadeira de escritório","Violão","Bicicleta","Cama box","Guarda roupas","Cama king","Sofá retrátil","Fogão","Micro-ondas","Guitarra","Celular ABXY","Bateria","Tablet ABXY","Lava louças","Secadora de roupas","Smart TV","Lavadora de roupas","Geladeira","TV Led UHD 4K","Celular Plus X42"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"origem=Loja 1\u003cbr\u003epreco=%{x}\u003cbr\u003eproduto=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgr ...

# %% [markdown]
# # Frete médio por loja
#
#     Loja 1: O frete médio é R$ 34.69 enquanto a mediana é R$ 16.5.
#     Loja 2: O frete médio é R$ 33.62 enquanto a mediana é R$ 15.41.
#     Loja 3: O frete médio é R$ 33.07 enquanto a mediana é R$ 15.88.
#     Loja 4: O frete médio é R$ 31.28 enquanto a mediana é R$ 14.61.
#
# A relação do frete/preco do produto em todas as lojas deu 5,33% o que significa que provavelmente quem criou a base usou esse fator para se chegar em um valor de frete.
#
#     Loja 1: A relação entre frete e faturamento é de: 5.333%.
#     Loja 2: A relação entre frete e faturamento é de: 5.329%.
#     Loja 3: A relação entre frete e faturamento é de: 5.329%.
#     Loja 4: A relação entre frete e faturamento é de: 5.327%.

# %% [markdown]
# ## Frete médio

# %%
def media_frete(loja, nome_loja):
  loja_frete_media = round(loja["frete"].mean(),2)
  loja_frete_mediana = round(loja["frete"].median(),2)
  return print(f'{nome_loja}: O frete médio é R$ {loja_frete_media} enquanto a mediana é R$ {loja_frete_mediana}.')

media_frete(loja1, 'Loja 1')
media_frete(loja2, 'Loja 2')
media_frete(loja3, 'Loja 3')
media_frete(loja4, 'Loja 4')
# Out:
# Loja 1: O frete médio é R$ 34.69 enquanto a mediana é R$ 16.5.
# Loja 2: O frete médio é R$ 33.62 enquanto a mediana é R$ 15.41.
# Loja 3: O frete médio é R$ 33.07 enquanto a mediana é R$ 15.88.
# Loja 4: O frete médio é R$ 31.28 enquanto a mediana é R$ 14.61.

# %% [markdown]
# ## Relação entre frete e faturamento

# %%
def frete_faturamento(loja, nome_loja):
  pct_frete_faturamento = loja["frete"].sum() / loja["preco"].sum()
  return print(f'{nome_loja}: A relação entre frete e faturamento é de: {pct_frete_faturamento:.3%}.')

frete_faturamento(loja1, 'Loja 1')
frete_faturamento(loja2, 'Loja 2')
frete_faturamento(loja3, 'Loja 3')
frete_faturamento(loja4, 'Loja 4')
# Out:
# Loja 1: A relação entre frete e faturamento é de: 5.333%.
# Loja 2: A relação entre frete e faturamento é de: 5.329%.
# Loja 3: A relação entre frete e faturamento é de: 5.329%.
# Loja 4: A relação entre frete e faturamento é de: 5.327%.

# %% [markdown]
# # Mapa de Vendas
#
# Mapa das 4 lojas ilustrando o estado de venda e a quantidade de vendas.

# %%
df_map = loja1.groupby(['lat','lon','local_compra'])['local_compra'].value_counts().reset_index().rename(columns={"count":"vendas"}).sort_values(by='vendas', ascending=False)
fig = px.scatter_geo(df_map, lat='lat', lon='lon', size='vendas', hover_name = 'local_compra', color = 'local_compra', projection='miller',
                     title='Mapa de vendas loja 1',width=1300,height=500, scope = 'south america')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c70f5d98-1922-4ab8-b3be-ad94409fa612" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c70f5d98-1922-4ab8-b3be-ad94409fa612")) {                    Plotly.newPlot(                        "c70f5d98-1922-4ab8-b3be-ad94409fa612",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SP\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SP"],"lat":[-22.19],"legendgroup":"SP","lon":[-48.79],"marker":{"color":"#636efa","size":[984],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"SP","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RJ\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RJ"],"lat":[-22.25],"legendgroup":"RJ","lon":[-42.66],"marker":{"color":"#EF553B","size":[298],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"RJ","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=MG\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["MG"],"lat":[-18.1],"legendgroup":"MG","lon":[-44.38],"marker":{"color":"#00cc96","size":[265],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"MG","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RS\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RS"],"lat":[-30.17],"legendgroup":"RS","lon":[-53.5],"marker":{"color":"#ab63fa","size":[155],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"RS","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=PR\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["PR"],"lat":[-24.89],"legendgroup":"PR","lon":[-51.55],"marker":{"color":"#FFA15A","size":[128],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"PR","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SC\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SC"],"lat":[-27.45],"legendgroup":"SC","lon":[-50.95],"marker":{"color":"#19d3f3","size":[95],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"SC","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=BA\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BA"],"lat":[-13.29],"legendgroup":"BA","lon":[-41.71],"marker":{"color":"#FF6692","size":[75],"sizemode":"area","sizeref":2.46,"symbol":"circle"},"mode":"markers","name":"BA","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=DF\u003cbr\u003evendas=%{m ...

# %%
df_map = loja2.groupby(['lat','lon','local_compra'])['local_compra'].value_counts().reset_index().rename(columns={"count":"vendas"}).sort_values(by='vendas', ascending=False)
fig = px.scatter_geo(df_map, lat='lat', lon='lon', size='vendas', hover_name = 'local_compra', color = 'local_compra', projection='miller',
                     title='Mapa de vendas loja 2', scope = 'south america')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b210f260-bf9f-40f1-9c31-ae83a1d48bec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b210f260-bf9f-40f1-9c31-ae83a1d48bec")) {                    Plotly.newPlot(                        "b210f260-bf9f-40f1-9c31-ae83a1d48bec",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SP\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SP"],"lat":[-22.19],"legendgroup":"SP","lon":[-48.79],"marker":{"color":"#636efa","size":[985],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"SP","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RJ\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RJ"],"lat":[-22.25],"legendgroup":"RJ","lon":[-42.66],"marker":{"color":"#EF553B","size":[311],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"RJ","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=MG\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["MG"],"lat":[-18.1],"legendgroup":"MG","lon":[-44.38],"marker":{"color":"#00cc96","size":[283],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"MG","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RS\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RS"],"lat":[-30.17],"legendgroup":"RS","lon":[-53.5],"marker":{"color":"#ab63fa","size":[124],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"RS","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=PR\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["PR"],"lat":[-24.89],"legendgroup":"PR","lon":[-51.55],"marker":{"color":"#FFA15A","size":[98],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"PR","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SC\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SC"],"lat":[-27.45],"legendgroup":"SC","lon":[-50.95],"marker":{"color":"#19d3f3","size":[94],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"SC","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=BA\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BA"],"lat":[-13.29],"legendgroup":"BA","lon":[-41.71],"marker":{"color":"#FF6692","size":[78],"sizemode":"area","sizeref":2.4625,"symbol":"circle"},"mode":"markers","name":"BA","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=DF\u003cbr\u003 ...

# %%
df_map = loja3.groupby(['lat','lon','local_compra'])['local_compra'].value_counts().reset_index().rename(columns={"count":"vendas"}).sort_values(by='vendas', ascending=False)
fig = px.scatter_geo(df_map, lat='lat', lon='lon', size='vendas', hover_name = 'local_compra', color = 'local_compra', projection='miller',
                     title='Mapa de vendas loja 3',width=1300,height=500, scope = 'south america')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb0521d8-a036-46ea-ae49-9e9218d446d2" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb0521d8-a036-46ea-ae49-9e9218d446d2")) {                    Plotly.newPlot(                        "bb0521d8-a036-46ea-ae49-9e9218d446d2",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SP\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SP"],"lat":[-22.19],"legendgroup":"SP","lon":[-48.79],"marker":{"color":"#636efa","size":[983],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"SP","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RJ\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RJ"],"lat":[-22.25],"legendgroup":"RJ","lon":[-42.66],"marker":{"color":"#EF553B","size":[295],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"RJ","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=MG\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["MG"],"lat":[-18.1],"legendgroup":"MG","lon":[-44.38],"marker":{"color":"#00cc96","size":[285],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"MG","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RS\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RS"],"lat":[-30.17],"legendgroup":"RS","lon":[-53.5],"marker":{"color":"#ab63fa","size":[128],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"RS","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=PR\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["PR"],"lat":[-24.89],"legendgroup":"PR","lon":[-51.55],"marker":{"color":"#FFA15A","size":[120],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"PR","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SC\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SC"],"lat":[-27.45],"legendgroup":"SC","lon":[-50.95],"marker":{"color":"#19d3f3","size":[77],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"SC","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=BA\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BA"],"lat":[-13.29],"legendgroup":"BA","lon":[-41.71],"marker":{"color":"#FF6692","size":[77],"sizemode":"area","sizeref":2.4575,"symbol":"circle"},"mode":"markers","name":"BA","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=ES\u003cbr\u ...

# %%
df_map = loja4.groupby(['lat','lon','local_compra'])['local_compra'].value_counts().reset_index().rename(columns={"count":"vendas"}).sort_values(by='vendas', ascending=False)
fig = px.scatter_geo(df_map, lat='lat', lon='lon', size='vendas', hover_name = 'local_compra', color = 'local_compra', projection='miller',
                     title='Mapa de vendas loja 4',width=1300,height=500, scope = 'south america')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8471504f-9514-4e5d-8601-c8e91891fd5d" class="plotly-graph-div" style="height:500px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8471504f-9514-4e5d-8601-c8e91891fd5d")) {                    Plotly.newPlot(                        "8471504f-9514-4e5d-8601-c8e91891fd5d",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SP\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SP"],"lat":[-22.19],"legendgroup":"SP","lon":[-48.79],"marker":{"color":"#636efa","size":[991],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"SP","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RJ\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RJ"],"lat":[-22.25],"legendgroup":"RJ","lon":[-42.66],"marker":{"color":"#EF553B","size":[308],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"RJ","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=MG\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["MG"],"lat":[-18.1],"legendgroup":"MG","lon":[-44.38],"marker":{"color":"#00cc96","size":[269],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"MG","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=RS\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["RS"],"lat":[-30.17],"legendgroup":"RS","lon":[-53.5],"marker":{"color":"#ab63fa","size":[127],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"RS","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=PR\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["PR"],"lat":[-24.89],"legendgroup":"PR","lon":[-51.55],"marker":{"color":"#FFA15A","size":[127],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"PR","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=SC\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["SC"],"lat":[-27.45],"legendgroup":"SC","lon":[-50.95],"marker":{"color":"#19d3f3","size":[80],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"SC","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=BA\u003cbr\u003evendas=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["BA"],"lat":[-13.29],"legendgroup":"BA","lon":[-41.71],"marker":{"color":"#FF6692","size":[80],"sizemode":"area","sizeref":2.4775,"symbol":"circle"},"mode":"markers","name":"BA","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocal_compra=DF\u003cbr\u ...

# %% [markdown]
# # Conclusão
# Baseado na análise exploratória apresentada anteriormente, temos:
#
# Faturamento:
#
#     A loja1 teve R$ 1,534,509.12 de faturamento total. Sendo responsável por 26.13% do total das lojas.
#     A loja2 teve R$ 1,488,459.06 de faturamento total. Sendo responsável por 25.35% do total das lojas.
#     A loja3 teve R$ 1,464,025.03 de faturamento total. Sendo responsável por 24.93% do total das lojas.
#     A loja4 teve R$ 1,384,497.58 de faturamento total. Sendo responsável por 23.58% do total das lojas.
#
# Nota média das avaliações:
#
#     Loja 1: A nota média das avaliações é 3.98 enquanto a mediana é 5.0.
#     Loja 2: A nota média das avaliações é 4.04 enquanto a mediana é 5.0.
#     Loja 3: A nota média das avaliações é 4.05 enquanto a mediana é 5.0.
#     Loja 4: A nota média das avaliações é 4.0 enquanto a mediana é 5.0.
#
# Categoria mais vendida:
#
#     Loja 1: A categoria mais vendida foi moveis com 465 vendas(19.71%).
#     A categoria menos vendida foi utilidades domesticas com 171 vendas(7.25%).
#     Loja 2: A categoria mais vendida foi moveis com 442 vendas(18.74%).
#     A categoria menos vendida foi utilidades domesticas com 181 vendas(7.67%).
#     Loja 3: A categoria mais vendida foi moveis com 499 vendas(21.15%).
#     A categoria menos vendida foi instrumentos musicais com 177 vendas(7.50%).
#     Loja 4: A categoria mais vendida foi moveis com 480 vendas(20.36%).
#     A categoria menos vendida foi instrumentos musicais com 170 vendas(7.21%).
#
# Frete:
#
#     Loja 1: O frete médio é R$ 34.69 enquanto a mediana é R$ 16.5.
#     Loja 2: O frete médio é R$ 33.62 enquanto a mediana é R$ 15.41.
#     Loja 3: O frete médio é R$ 33.07 enquanto a mediana é R$ 15.88.
#     Loja 4: O frete médio é R$ 31.28 enquanto a mediana é R$ 14.61.
#
# Mesmo a loja 1 tendo a pior das avaliações, ela possui o maior faturamento, enquanto a loja 4 tem o menor faturamento e segunda pior nota de avaliação.
# Todas lojas tiveram como categoria mais vendida os móveis.
# Já o frete se mostrou  mais barato na loja 4, o que pode sinalizar que esta loja atinge um público mais próximo de sua localização, ou pode estar vendendo produtos que possuem frete menor.
#
#
# Analisando apenas os dados disponíveis, **eu escolho a loja 4 para ser vendida** baseada no faturamento e avaliação, mas sugiro avaliar outras métricas que não estão presentes aqui, como a margem de cada loja.
